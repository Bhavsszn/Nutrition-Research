# %%
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
exe_df = pd.read_csv('exercise_data.csv')
exe_df.shape

food_df = pd.read_csv('food.csv')
food_df
# Out:
#              name emoji  Calories (kcal)  Carbohydrates (g)  Total Sugar (g)  \
# 0          grapes     🍇             0.69             0.1810           0.1548
# 1           melon     🍈             0.28             0.0658           0.0569
# 2      watermelon     🍉             0.30             0.0755           0.0620
# 3       tangerine     🍊             0.53             0.1334           0.1058
# 4           lemon     🍋             0.29             0.0932           0.0250
# 5          banana     🍌             0.89             0.2284           0.1223
# 6       pineapple     🍍             0.50             0.1312           0.0985
# 7       red apple     🍎             0.63             0.1522           0.1168
# 8     green apple     🍏             0.58             0.1361           0.0959
# 9            pear     🍐             0.57             0.1523           0.0975
# 10          peach     🍑             0.39             0.0954           0.0839
# ...

# %%
unique_user_ids = exe_df['User_ID'].unique()
num_unique_user_ids = len(unique_user_ids)
print(num_unique_user_ids)
# Out:
# 3301

# %%
exe_df.replace({"Gender":{'male':0,'female':1}}, inplace=True)
exe_df.head()
# Out:
# /var/folders/tw/sghw4g895mn7xllnlkt87nq00000gn/T/ipykernel_42600/4270794233.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   exe_df.replace({"Gender":{'male':0,'female':1}}, inplace=True)
#     User_ID                            Exercise_Type  Gender  Age  Height  \
# 0  10796536     Climbing hills, carrying 21 to 42 lb       0   65   179.0
# 1  19207815     Climbing hills, carrying up to 9 lbs       1   33   159.0
# 2  11260824  Track and field (high jump, pole vault)       1   23   161.0
# 3  12388580                                  Curling       1   27   175.0
# 4  14580760                                    Rugby       1   41   173.0
#
#    Weight  Duration  Heart_Rate  Body_Temp  Total_Calories_Burned
# ...

# %%
exe_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3720 entries, 0 to 3719
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   User_ID                3720 non-null   int64
#  1   Exercise_Type          3720 non-null   object
#  2   Gender                 3720 non-null   int64
#  3   Age                    3720 non-null   int64
#  4   Height                 3720 non-null   float64
#  5   Weight                 3720 non-null   float64
#  6   Duration               3720 non-null   float64
#  7   Heart_Rate             3720 non-null   float64
#  8   Body_Temp              3720 non-null   float64
#  9   Total_Calories_Burned  3720 non-null   float64
# dtypes: float64(6), int64(3), object(1)
# memory usage: 290.8+ KB

# %%
def clean_exercise_type(exercise_type):
    cleaned_type = re.sub("[^a-zA-Z0-9 ]", "", exercise_type)
    return cleaned_type

exe_df["clean_exercise_type"] = exe_df["Exercise_Type"].apply(clean_exercise_type)
exe_df
# Out:
#        User_ID                            Exercise_Type  Gender  Age  Height  \
# 0     10796536     Climbing hills, carrying 21 to 42 lb       0   65   179.0
# 1     19207815     Climbing hills, carrying up to 9 lbs       1   33   159.0
# 2     11260824  Track and field (high jump, pole vault)       1   23   161.0
# 3     12388580                                  Curling       1   27   175.0
# 4     14580760                                    Rugby       1   41   173.0
# ...        ...                                      ...     ...  ...     ...
# 3715  17731023                     Golf, miniature golf       0   77   187.0
# 3716  15090337                          Tennis, singles       1   24   180.0
# 3717  17454866             Basketball, shooting baskets       1   35   167.0
# 3718  19122789                                  Tai chi       1   28   158.0
# 3719  19119246    Cycling, 16-19 mph, very fast, racing       0   32   177.0
#
# ...

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 2))
tfidf = vectorizer.fit_transform(exe_df["clean_exercise_type"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def search(exercise_type_name):
# exercise_type_name = "Climbing"
    exercise_type_name = clean_exercise_type(exercise_type_name)
    query_vec = vectorizer.transform([exercise_type_name])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]
    results = exe_df.iloc[indices][::-1]
    return results

# %%
import ipywidgets as widgets
from IPython.display import display

exercise_input = widgets.Text(
    value = "Basketball",
    description = "Exercises",
    disabled = False

)

exercise_list = widgets.Output()

# def search(title):
#     # Placeholder function for demonstration
#     return widgets.HTML(value=f"<b>Search Results for:</b> {title}")


def on_type(data):
    with exercise_list:
        exercise_list.clear_output()
        title = data["new"]
        if len(title) > 5:
            display(search(title))
        
exercise_input.observe(on_type, names = 'value')

display(exercise_input, exercise_list)
# Out:
# Text(value='Basketball', description='Exercises')
# Output()

# %%
user_age = 23
user_gender = 0  # Assuming "0" represents one gender (e.g., male)

similar_exercises = exe_df[(exe_df["Age"] == user_age) & (exe_df["Gender"] == user_gender)]["clean_exercise_type"]

# similar_users = exe_df[(exe_df["Age"] == user_age) & (exe_df["Gender"] == 0)]["User_ID"]
similar_exercises
# Out:
# 11                                   Orienteering
# 194                     Running 8 mph 75 min mile
# 267                                  Snow shoeing
# 427                               Walking the dog
# 430                     Walking 40 mph very brisk
# 513           Childrens games hopscotch dodgeball
# 551                                  Ski mobiling
# 593                             Jumping rope slow
# 622                   Basketball game competitive
# 713                     Running 86 mph 7 min mile
# 1060               Golf walking and pulling clubs
# 1074                               Boxing in ring
# 1305                           Darts wall or lawn
# 1308                      Racquetball competitive
# 1310                                    Wrestling
# 1317                 Running 5 mph 12 minute mile
# 1389                                       Squash
# 1485                        Basketball wheelchair
# 1517                         Hiking cross country
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

exe_df['clean_exercise_type'] = exe_df['clean_exercise_type'].fillna('')

# Vectorizing the exercise types
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(exe_df['clean_exercise_type'])

# Calculateing similarity scores between exercise types
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

def recommend_exercise(age, gender, calories_burned, top_n=5):
    filtered_exercises = exe_df[(exe_df['Age'] == age) & (exe_df['Gender'] == gender) &
                                (exe_df['Total_Calories_Burned'] >= calories_burned)]

    # indices of filtered exercises
    indices = filtered_exercises.index.tolist()
    similarity_scores = cosine_sim[indices].sum(axis=0)

    # indices of top recommended exercises
    top_indices = similarity_scores.argsort()[::-1][:top_n]

    #exercise types corresponding to the top indices
    recommended_exercises = exe_df.iloc[top_indices]['Exercise_Type'].tolist()

    return recommended_exercises


age = 45
gender = 1 
calories_burned = 45 
recommended_exercises = recommend_exercise(age, gender, calories_burned)
print("Recommended Exercises:", recommended_exercises)
# Out:
# Recommended Exercises: ['Canoeing, rowing, vigorous', 'Canoeing, rowing, vigorous', 'Canoeing, rowing, vigorous', 'Canoeing, rowing, vigorous', 'Canoeing, rowing, vigorous']

# %%
#Food recommendation

# Vectorizing food names
vectorizer_food = TfidfVectorizer(stop_words='english')
tfidf_matrix_food = vectorizer_food.fit_transform(food_df['name'])

# Calculate similarity scores between food items
cosine_sim_food = linear_kernel(tfidf_matrix_food, tfidf_matrix_food)

def recommend_food(age, gender, desired_calories, top_n=5):
    # Filtering food items based on user preferences
    filtered_food = food_df[(food_df['Calories (kcal)'] <= desired_calories)]

    # Indices of filtered food items
    indices_food = filtered_food.index.tolist()
    similarity_scores_food = cosine_sim_food[indices_food].sum(axis=0)

    top_indices_food = similarity_scores_food.argsort()[::-1][:top_n]

    # Food items corresponding to the top indices
    recommended_food = food_df.iloc[top_indices_food]['name'].tolist()

    return recommended_food

age = 45
gender = 1 
desired_calories = 900  # Adjust this according to user preference
recommended_food = recommend_food(age, gender, desired_calories)
print("Recommended Food:", recommended_food)
# Out:
# Recommended Food: ['french bread', 'red apple', 'bread', 'rice', 'rice crackers']
